# %% [markdown]
# <a href="https://colab.research.google.com/github/sCesca/Data-Science/blob/main/SympyAndLatex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sympy e LaTeX
# ---
#
#
#
# **Sympy** possibilita com que sejam criados símbolos e formas mais atrativas de se representar uma variável em Python.
#
# Além disso, possui métodos que representam fórmulas e funções para auxiliar no entendimento de um possível output visual.
#
#
#
# *   **Objetivo:** Prover representações simbólicas à linguagem Python
# *   **Features:**
#
#  → Aritmética básica
#
#  → Simplificações
#
#  → Expansões de equações
#
#  → Funções: trignométricas, hiperbólicas, exponenciais, logarítmicas e afins
#
#  → Substituições
#
#  → Precisão arbitrária de inteiros, racionais e decimais
#
#  → Símbolos não comutativos
#
#  → Correspondência
#
#
# *   **Polinômios**
#
#   → Aritmética com polinômios
#
#   → Fatorização
#
#   → Square-free decomposition
#
#   → Bases de Grobner
#
#   → Decomposição em frações parciais
#
#   → Resultantes
#
# *   Cálculo
#
#   → Limites
#
#   → Diferenciação
#
#   → Integrais
#
#   → Séries de Taylor (Laurent)
#
# *   Resolvendo equações
#
#   → Equação polinomial
#
#   → Equação algébrica
#
#   → Equação diferencial
#
#   → Diferença entre equações
#
#   → Sistemas de Equações
#
# *   Combinatória
#
#   → Permutação
#
#   → Combinação
#
#   → Partição
#
#   → Subsets
#
# *   Matemática Discreta
#
#   → Coeficientes binomiais
#
#   → Somatórios
#
#   → Produtos
#
#   → Teoria dos Números
#
#   → Expressões Lógicas
#
# *   Matrizes
#
#   → Aritmética básica
#
#   → Autovalores e autovetores
#
#   → Determinantes
#
#   → Inversões
#
#   → Expressões abstratas
#
#   → Resoluções
#
# *   Álgebra Geométrica
#
# *   Geometria
#
#   → Pontos, linhas, segmentos, elípses, círculos e polígonos
#
#   → Intersecções
#
#   → Tangentes
#
#   → Similaridades
#
# *   Plotagem
#
#   → Modos de coordenadas
#
#   → Plotagem geométrica de entidades
#
#   → 2D e 3D
#
#   → Interfaces interativas
#
#   → Cores
#
# *   Física
#
#   → Unidades
#
#   → Mecânica
#
#   → Quântica
#
#   → Ótica Gaussian
#
#   → Álgebra de Pauli
#
# *   Estatística
#
#   → Distruibuição normal
#
#   → Distruibuição uniforme
#
#   → Probabilidade
#
# *   Impressões
#
#   → Impressões bonitas: ASCII/Unicode, LaTeX
#
#   → Geração de códigos: C, Fortran, Python![CheatsheetSympy.png](data:image/png;base64,...![CheatsheetSympy.jpg](data:image/jpeg;base64,...![CheatsheetSympy.jpg](data:image/jpeg;base64,...)))

# %%
import numpy as np
import sympy as sym
sym.init_printing()
from IPython.display import Math, display

# %%
x, y, z = sym.symbols('x, y, z')

# %%
x, y, z
# Out:
# (x, y, z)

# %%
x**2 + y + 4**2 + y**x
# Out:
#  2        x
# x  + y + y  + 16

# %%
print(x**2 + y + 4**2 + y**x)
# Out:
# x**2 + y + y**x + 16

# %%
display(x**2 + y + 4**2 + y**x)
print('-------')
display(x**y / x)
# Out:
#  2        x
# x  + y + y  + 16
# -------
#  y
# x
# ──
# x

# %%
display(np.sqrt(2))
print('-------')
display(sym.sqrt(2))
# Out:
# 1.4142135623730951
# -------
# √2

# %%
# Sympy - exercises

x, y = sym.symbols('x, y')

# 1)
display(y * x**2)

# 2)
display(sym.sqrt(4) * x)

# 3)
display(sym.sqrt(x) * sym.sqrt(x))
# Out:
#  2
# x ⋅y
# 2⋅x
# x

# %%
display(Math('4 + 3 = 7'))
# Out:
# $\displaystyle 4 + 3 = 7$

# %%
display(Math('\\sigma = \\mu \\times \\sqrt{5}'))
# Out:
# $\displaystyle \sigma = \mu \times \sqrt{5}$

# %%
display(Math('x_{x \\times y} + y^{x \\times y - 2k - 15 \\div 4}'))
# Out:
# $\displaystyle x_{x \times y} + y^{x \times y - 2k - 15 \div 4}$

# %%
# Sympy exercise resolved with LaTex

# 1)
display(Math('y \\times x^{2}'))

# 2)
display(Math('\\sqrt{4} \\times x'))

# 3)
display(Math('\\sqrt{x}\\sqrt{x}'))
# Out:
# $\displaystyle y \times x^{2}$
# $\displaystyle \sqrt{4} \times x$
# $\displaystyle \sqrt{x}\sqrt{x}$
# $\displaystyle \frac{1+x}{2v + \sqrt{4^{xt}}}$

# %%
display(Math('\\text{The answer to this equation is: } \\frac{1+x}{2v + \\sqrt{4^{xt}}}'))
# Out:
# $\displaystyle \text{The answer to this equation is: } \frac{1+x}{2v + \sqrt{4^{xt}}}$

# %% [markdown]
# ## This is a Markdown
#
# This cell is not for running actual Python code. We can make the following math expression: $\frac{1+x}{2v + \sqrt{4^{xt}}}$
#
# **LaTeX Exercises in markdown**
#
# 1) $4x + 5y - 8z = 17$
#
# 2) $\sin(2\pi ft + \theta)$
#
# 3) $e = mc²$
#
# 4) $\frac{4 + 5x²}{(1 + x) (1 -x)}$

# %%
# LaTeX exercises

# 1)
display(Math('\\text{1) }4x + 5x - 8z = 17'))

# 2)
display(Math('\\text{2) }\\sin(2\\pi f t + \\theta)'))

# 3)
display(Math('\\text{3) }e = mc²'))

# 4)
display(Math('\\text{4) }\\frac{4 + 5x²}{(1 + x)(1 - x)}'))

# Example with variable

x = 50
y = 10

display(Math('\\text{Um exemplo utilizando variáveis X e Y: }\\frac{%g}{%g} = %g' %(x, y, x/y)))
# Out:
# $\displaystyle \text{1) }4x + 5x - 8z = 17$
# $\displaystyle \text{2) }\sin(2\pi f t + \theta)$
# $\displaystyle \text{3) }e = mc²$
# $\displaystyle \text{4) }\frac{4 + 5x²}{(1 + x)(1 - x)}$
# $\displaystyle \text{Um exemplo utilizando variáveis X e Y: }\frac{50}{10} = 5$

# %%
mu, alpha, sigma = sym.symbols('mu, alpha, sigma')

expr = sym.exp( (mu-alpha)**2 / (2*sigma**2) )
display(expr)
# Out:
#          2
#  (-α + μ)
#  ─────────
#        2
#     2⋅σ
# ℯ

# %%
hello = sym.symbols('Samuel')
hello/3
# Out:
# Samuel
# ──────
#   3

# %%
x = sym.symbols('x')
expr = x + 4
expr
# Out:
# x + 4

# %%
expr.subs(x, 6)
# Out:
# 10

# %%
x, y = sym.symbols('x, y')

expr = x + 4 + 2**y

expr.subs({x: -4, y: 2})
# Out:
# 4

# %%
t = sym.symbols('t')
expr = 3 / 2**t

print(sym.latex(expr))

display(Math(sym.latex(expr)))
# Out:
# 3 \cdot 2^{- t}
# $\displaystyle 3 \cdot 2^{- t}$

# %%
expr = 3 / t
sym.latex(sym.sympify('3/4'))
# Out:
# '\\frac{3}{4}'

# %% [markdown]
# **Sympy and Latex challenge**
#
# With x = -2 : x² + 4 => -2² + 4 = 8
#
# With x = -1 : x² + 4 => -1² + 4 = 5
#
# With x = 0 : x² + 4 => 0² + 4 = 4
#
# With x = 1 : x² + 4 => 1² + 4 = 5
#
# With x = 2 : x² + 4 => 2² + 4 = 8

# %%
x = sym.symbols('x')

expr = x**2 + 4

for i in range(-10, 10) :
  ans = (x + 4).subs(x, i**2)

  # ou expr.subs(x, i)) no terceiro parâmetro do output

  display(Math('\\text{With } x = %g; x^2 + 4 \\quad \\Rightarrow \\quad %g² + 4 = %g' %(i, i, ans)))
# Out:
# $\displaystyle \text{With } x = -10; x^2 + 4 \quad \Rightarrow \quad -10² + 4 = 104$
# $\displaystyle \text{With } x = -9; x^2 + 4 \quad \Rightarrow \quad -9² + 4 = 85$
# $\displaystyle \text{With } x = -8; x^2 + 4 \quad \Rightarrow \quad -8² + 4 = 68$
# $\displaystyle \text{With } x = -7; x^2 + 4 \quad \Rightarrow \quad -7² + 4 = 53$
# $\displaystyle \text{With } x = -6; x^2 + 4 \quad \Rightarrow \quad -6² + 4 = 40$
# $\displaystyle \text{With } x = -5; x^2 + 4 \quad \Rightarrow \quad -5² + 4 = 29$
# $\displaystyle \text{With } x = -4; x^2 + 4 \quad \Rightarrow \quad -4² + 4 = 20$
# $\displaystyle \text{With } x = -3; x^2 + 4 \quad \Rightarrow \quad -3² + 4 = 13$
# $\displaystyle \text{With } x = -2; x^2 + 4 \quad \Rightarrow \quad -2² + 4 = 8$
# $\displaystyle \text{With } x = -1; x^2 + 4 \quad \Rightarrow \quad -1² + 4 = 5$
# $\displaystyle \text{With } x = 0; x^2 + 4 \quad \Rightarrow \quad 0² + 4 = 4$
# $\displaystyle \text{With } x = 1; x^2 + 4 \quad \Rightarrow \quad 1² + 4 = 5$
# $\displaystyle \text{With } x = 2; x^2 + 4 \quad \Rightarrow \quad 2² + 4 = 8$
# $\displaystyle \text{With } x = 3; x^2 + 4 \quad \Rightarrow \quad 3² + 4 = 13$
# $\displaystyle \text{With } x = 4; x^2 + 4 \quad \Rightarrow \quad 4² + 4 = 20$
# $\displaystyle \text{With } x = 5; x^2 + 4 \quad \Rightarrow \quad 5² + 4 = 29$
# $\displaystyle \text{With } x = 6; x^2 + 4 \quad \Rightarrow \quad 6² + 4 = 40$
# $\displaystyle \text{With } x = 7; x^2 + 4 \quad \Rightarrow \quad 7² + 4 = 53$
# $\displaystyle \text{With } x = 8; x^2 + 4 \quad \Rightarrow \quad 8² + 4 = 68$
# $\displaystyle \text{With } x = 9; x^2 + 4 \quad \Rightarrow \quad 9² + 4 = 85$

# %%
# f-strings
x, y = sym.symbols('x, y')
display(Math(f'\\frac{{x}}{{y}}'))

expr = 3 / x

display(Math(f'\\text{{Utilizando f-strings com latex: }}\\frac{{{sym.latex(expr)}}}{{{y}}}'))
display(Math('\\text{Utilizando porcentagem para imprimir valores: } \\frac{%s}{%s}' %(sym.latex(expr), y)))
# Out:
# $\displaystyle \frac{x}{y}$
# $\displaystyle \text{Utilizando f-strings com latex: }\frac{\frac{3}{x}}{y}$
# $\displaystyle \text{Utilizando porcentagem para imprimir valores: } \frac{\frac{3}{x}}{y}$

# %% [markdown]
# **Use Sympy to understand the law of exponents**
#
# $x^y\times x^z = x^{y+z}$
#
# $\frac{x^y}{x^z} = x^y \times x^{-z} = x^{y-z}$
#
# $x^y \times y^z = x^y \times y^z$

# %%
x, y, z = sym.symbols('x, y, z')

expr = x**y * x**z
expr2 = x**y / x**z
expr3 = x**y * y**z

display(Math('%s = %s' %(sym.latex(expr), sym.latex(sym.simplify(expr)))))
display(Math('%s = %s' %(sym.latex(expr2), sym.latex(sym.simplify(expr2)))))
display(Math('%s = %s' %(sym.latex(expr3), sym.latex(sym.simplify(expr3)))))
# Out:
# $\displaystyle x^{y} x^{z} = x^{y + z}$
# $\displaystyle x^{y} x^{- z} = x^{y - z}$
# $\displaystyle x^{y} y^{z} = x^{y} y^{z}$

# %%
sym.Eq(expr, sym.simplify(expr))
# Out:
#  y  z    y + z
# x ⋅x  = x

# %%
display(sym.powsimp(expr))
# Out:
#  y + z
# x

# %% [markdown]
# # **Sympy and LaTeX: Bug hunt!**

# %%
mu, alpha = sym.symbols('mu, alpha')

expr = 2 * sym.exp(mu**2 / alpha)

display(Math(sym.latex(expr)))

# %%
display(Math('1234 + \\frac{3x}{\\sin(2\\pi t+\\theta)}'))
# Out:
# $\displaystyle 1234 + \frac{3x}{\sin(2\pi t+\theta)}$

# %%
a = '3'
b = '2'

print(sym.sympify(int(a)+int(b)))
# Out:
# 5

# %%
x = 1/2
sym.Eq(2, 4*x)
# Out:
# True

# %%
q = t**2
r = t**2

display(q)
display(r)

q = sym.sympify('x²')
r = sym.sympify('x**2')

sym.Eq(q, r)
# Out:
#  2
# t
#  2
# t
#       2
# x² = x

# %%
x = sym.symbols('x')

equation = (4*x**2 - 5*x + 10)**(1/2)

display(equation)
equation.subs(x, 3)
# Out:
#                  0.5
# ⎛   2           ⎞
# ⎝4⋅x  - 5⋅x + 10⎠
# 5.56776436283002

# %%
x, y = sym.symbols('x, y')

equation = 1/4*x*y**2 - x*(5*x + 10*y**2)**(3)
display(equation)
# Out:
#                            3
#         2     ⎛          2⎞
# 0.25⋅x⋅y  - x⋅⎝5⋅x + 10⋅y ⎠

# %% [markdown]
# ### 1) Algumas funções de simplificação de Sympy
#
#
# ---
#
#
# |    |   |
# |:---|:---|
# | expand | Expande a expressão |
# | factor | Fatora o polinômio até se tornar irredutível |
# | collect | Coleta os coeficientes dos polinômios |
# | cancel | Reescreve uma função racional como p / q com fatores comuns cancelados |
# | apart | Computa a fração parcial decomposta de uma função racional |
# | trigsimp | Simplifica uma expressão trigonométrica |
# | hyperexpand | Expande funções hipergeométricas |
